# %% [markdown]
# # Importing required Libraries

# %%
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing excel file
df = pd.read_csv("C:/Users/Vasu/Desktop/LOAN Prediction/Loan Pred excel.csv")

# %% [markdown]
# # Basic Operations

# %%
df.head(10)
# Out:
#   loan_application_id application_date  credit_score  loan_type loan_category  \
# 0            LA797244        10-Dec-14           519  Unsecured      Personal
# 1            LA332545        13-Dec-14           843  Unsecured     Education
# 2            LA576129        08-Dec-14           727  Unsecured      Personal
# 3            LA633665        18-Dec-14           394  Unsecured      Personal
# 4            LA164827        17-Dec-14           554  Unsecured      Personal
# 5            LA313841        22-Dec-14           730  Unsecured     Education
# 6            LA538959        23-Oct-15           316  Unsecured     Education
# 7            LA085669        29-Oct-16           737  Unsecured      Personal
# 8            LA247120        28-Apr-16           760  Unsecured      Personal
# 9            LA252975        03-Oct-16           404  Unsecured      Personal
#
#    interest_rate     loan_amount  loan_term asset_value interest_amount  ...  \
# ...

# %%
# Replace "₹ 0.00" with NaN in "asset_value" column
df['asset_value'] = df['asset_value'].replace("₹ 0.00", np.nan)

# %%
df['total_loan_amount'].value_counts().get(0, 0)
# Out:
# 585

# %%
df['status'].value_counts()
# Out:
# status
# Approved       982
# Rejected       339
# In progress    246
# Name: count, dtype: int64

# %%
df['total_loan_amount'] = df['total_loan_amount'].replace("₹ 0.00", np.nan)

# %%
df
# Out:
#      loan_application_id application_date  credit_score  loan_type  \
# 0               LA797244        10-Dec-14           519  Unsecured
# 1               LA332545        13-Dec-14           843  Unsecured
# 2               LA576129        08-Dec-14           727  Unsecured
# 3               LA633665        18-Dec-14           394  Unsecured
# 4               LA164827        17-Dec-14           554  Unsecured
# ...                  ...              ...           ...        ...
# 1562            LA677952        06-Dec-22           547  Unsecured
# 1563            LA947692        31-Aug-23           659  Unsecured
# 1564            LA706547        29-Jun-23           609  Unsecured
# 1565            LA182797        17-Jan-23           693  Unsecured
# 1566            LA799321        12-May-23           646  Unsecured
#
#      loan_category  interest_rate     loan_amount  loan_term asset_value  \
# 0         Personal       5.000000   ₹ 6,59,475.00         42         NaN
# ...

# %%
# Information about DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   loan_application_id              1567 non-null   object
#  1   application_date                 1567 non-null   object
#  2   credit_score                     1567 non-null   int64
#  3   loan_type                        1567 non-null   object
#  4   loan_category                    1567 non-null   object
#  5   interest_rate                    1567 non-null   float64
#  6   loan_amount                      1567 non-null   object
#  7   loan_term                        1567 non-null   int64
#  8   asset_value                      795 non-null    object
#  9   interest_amount                  1567 non-null   object
#  10  coapplicant_name                 1567 non-null   object
#  11  coapplicant_income               1567 non-null   object
# ...

# %% [markdown]
# ## Datatype Conversion

# %%
# List of columns to convert to integer
columns_to_convert = ["account_balance", "customer_income", "loan_amount", "asset_value", "interest_amount", "total_loan_amount", "coapplicant_income", "loan_amount_paid", "loan_amount_due"]

# Remove non-numeric characters and whitespaces, then convert to integer
for column in columns_to_convert:
    df[column] = df[column].str.replace('₹', '').str.replace(',', '').str.strip()
    # Convert to numeric
    df[column] = pd.to_numeric(df[column], errors='coerce', downcast='integer')

# %%
df.describe()
# Out:
#        credit_score  interest_rate   loan_amount    loan_term   asset_value  \
# count   1567.000000    1567.000000  1.567000e+03  1567.000000  7.950000e+02
# mean     575.529675       6.573607  1.492695e+06    44.065093  1.827663e+06
# std      156.431744       1.704933  1.836413e+06    15.022532  2.524095e+06
# min      300.000000       2.036817  4.100000e+04    24.000000  5.119600e+04
# 25%      447.000000       5.216322  3.828760e+05    33.000000  3.465925e+05
# 50%      573.000000       7.000000  8.150550e+05    43.000000  7.240480e+05
# 75%      710.000000       8.000000  1.763460e+06    53.000000  1.467894e+06
# max      850.000000      10.000000  1.491790e+07   120.000000  9.939018e+06
#
#        interest_amount  coapplicant_income  loan_interest_rate  \
# count     1.567000e+03        1.567000e+03         1567.000000
# mean      3.483003e+05        1.045608e+06            4.098856
# std       4.562999e+05        5.510839e+05            3.441094
# ...

# %%
df. columns
# Out:
# Index(['loan_application_id', 'application_date', 'credit_score', 'loan_type',
#        'loan_category', 'interest_rate', 'loan_amount', 'loan_term',
#        'asset_value', 'interest_amount', 'coapplicant_name',
#        'coapplicant_income', 'status', 'loan_account_id', 'loan_interest_rate',
#        'loan_approved_date', 'loan_amount_availed', 'total_loan_amount',
#        'loan_amount_due', 'loan_status', 'loan_amount_paid',
#        'loan_completion_date', 'Customer Name', 'customer_gender',
#        'customer_age', 'customer_marital_status', 'customer_no_of_dependents',
#        'customer_education', 'customer_income', 'customer_occupation',
#        'customer_person_with_disability', 'customer_address',
#        'customer_date_of_joining', 'account_number', 'account_type',
#        'minimum_balance', 'account_balance', 'account_interest_rate',
#        'has_debit', 'has_credit', 'has_chequebook', 'has_netbanking',
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Categorical Features

# %% [markdown]
# ### Loan Type

# %%
print('Visualization of Loan Types:')
print(df['loan_type'].value_counts())
sns.countplot(x='loan_type', data=df, palette='Set1')
# Out:
# Visualization of Loan Types:
# loan_type
# Secured      795
# Unsecured    772
# Name: count, dtype: int64
# <Axes: xlabel='loan_type', ylabel='count'>

# %% [markdown]
# ### Loan Category

# %%
print('Visualization of loan_category:')
print(df['loan_category'].value_counts())
sns.countplot(x='loan_category', data=df, palette='Set1')
# Out:
# Visualization of loan_category:
# loan_category
# Personal       556
# Gold           219
# Vehicle        209
# Home           207
# Agriculture    160
# Business       125
# Education       91
# Name: count, dtype: int64
# <Axes: xlabel='loan_category', ylabel='count'>

# %% [markdown]
# ### Status

# %%
print('Visualization of status:')
print(df['status'].value_counts())
sns.countplot(x='status', data=df, palette='Set1')
# Out:
# Visualization of status:
# status
# Approved       982
# Rejected       339
# In progress    246
# Name: count, dtype: int64
# <Axes: xlabel='status', ylabel='count'>

# %% [markdown]
# ### Gender

# %%
print('Visualization of customer_gender:')
print(df['customer_gender'].value_counts())
sns.countplot(x='customer_gender', data=df, palette='Set1')
# Out:
# Visualization of customer_gender:
# customer_gender
# Male      812
# Female    609
# Other     146
# Name: count, dtype: int64
# <Axes: xlabel='customer_gender', ylabel='count'>

# %% [markdown]
# ### Customer Occupation

# %%
print('Visualization of')
print(df['customer_occupation'].value_counts())
sns.countplot(x='customer_occupation', data=df, palette='Set1')
plt.xticks(rotation=45)
# Out:
# Visualization of
# customer_occupation
# Other            379
# Agri Allied      315
# Student          200
# Retired          183
# Business         138
# Self Employed    127
# Professional     126
# Salaried          99
# Name: count, dtype: int64
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Retired'),
#   Text(1, 0, 'Student'),
#   Text(2, 0, 'Agri Allied'),
#   Text(3, 0, 'Other'),
#   Text(4, 0, 'Salaried'),
#   Text(5, 0, 'Business'),
#   Text(6, 0, 'Self Employed'),
#   Text(7, 0, 'Professional')])

# %% [markdown]
# ### Account Type

# %%
df['account_type'].value_counts()
print('Visualization of account_type:')
print(df['account_type'].value_counts())
sns.countplot(x='account_type', data=df, palette='Set1')
# Out:
# Visualization of account_type:
# account_type
# Savings    727
# Current    337
# Name: count, dtype: int64
# <Axes: xlabel='account_type', ylabel='count'>

# %% [markdown]
# ### Account Status

# %%
df['account_status'].value_counts()
print('Visualization of account_status:')
print(df['account_status'].value_counts())
sns.countplot(x='account_status', data=df, palette='Set1')
# Out:
# Visualization of account_status:
# account_status
# Active    752
# Frozen    189
# Closed    123
# Name: count, dtype: int64
# <Axes: xlabel='account_status', ylabel='count'>

# %% [markdown]
# ### Marital Status

# %%
df['customer_marital_status'].value_counts()
print('Visualization of customer_marital_status:')
print(df['customer_marital_status'].value_counts())
sns.countplot(x='customer_marital_status', data=df, palette='Set1')
# Out:
# Visualization of customer_marital_status:
# customer_marital_status
# Married     862
# Single      583
# Divorced    122
# Name: count, dtype: int64
# <Axes: xlabel='customer_marital_status', ylabel='count'>

# %% [markdown]
# ### Number of dependents

# %%
df['customer_no_of_dependents'].value_counts()
print('Visualization of customer_no_of_dependents:')
print(df['customer_no_of_dependents'].value_counts())
sns.countplot(x='customer_no_of_dependents', data=df, palette='Set1')
# Out:
# Visualization of customer_no_of_dependents:
# customer_no_of_dependents
# 3    249
# 1    236
# 0    230
# 4    228
# 2    218
# 5    209
# 6    197
# Name: count, dtype: int64
# <Axes: xlabel='customer_no_of_dependents', ylabel='count'>

# %% [markdown]
# ### Customer Education

# %%
df['customer_education'].value_counts()
print('Visualization of customer_education:')
print(df['customer_education'].value_counts())
sns.countplot(x='customer_education', data=df, palette='Set1')
# Out:
# Visualization of customer_education:
# customer_education
# Matriculate      501
# Graduate         337
# Other            301
# Post Graduate    286
# Illiterate       142
# Name: count, dtype: int64
# <Axes: xlabel='customer_education', ylabel='count'>

# %% [markdown]
# ### Branch name

# %%
print('Visualization of branch_name:')
print(df['branch_name'].value_counts())
sns.countplot(x='branch_name', data=df, palette='Set1')
# Out:
# Visualization of branch_name:
# branch_name
# Roy Nagar      458
# Aggarwal       417
# Kapoor Zila    317
# Datta          238
# Balan Road     137
# Name: count, dtype: int64
# <Axes: xlabel='branch_name', ylabel='count'>

# %% [markdown]
# ###  Loan Approved

# %%
print('Visualization of Loan Approved ?:')
print(df['Loan Approved ?'].value_counts())
sns.countplot(x='Loan Approved ?', data=df, palette='Set1')
# Out:
# Visualization of Loan Approved ?:
# Loan Approved ?
# Yes    982
# No     585
# Name: count, dtype: int64
# <Axes: xlabel='Loan Approved ?', ylabel='count'>

# %% [markdown]
# - 795 of the loans are secured and 772 of them are Unsecured
# - Out of 1567 customers 556 of them opted for Personal Loan Category
# - out of 1567 Loans 982 of them got approved
# - Male customers are higher compared to female and others category
# - Among 1567 customers, 727 hold Savings accounts while 337 have Current accounts
# - 752 of the customer's account is Active
# - 862 of the Customers are Married
# - Matriculate is the highest of all the other Customer Education
# - Among 1567 loans, 982 of them are Approved

# %% [markdown]
# ## 2. Numerical Features

# %% [markdown]
# ### Distribution of Customer Income

# %%
df['customer_income'].value_counts()
# Out:
# customer_income
# 323983.0     3
# 1518712.0    3
# 365185.0     3
# 1650203.0    3
# 477148.0     3
#             ..
# 299848.0     1
# 695164.0     1
# 718556.0     1
# 1681907.0    1
# 507918.0     1
# Name: count, Length: 1100, dtype: int64

# %%
sns.distplot(df['customer_income'])
plt.show()
df['customer_income'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\Vasu\AppData\Local\Temp\ipykernel_7604\2615089840.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['customer_income'])

# %% [markdown]
# ### Distribution of CoApplicant Income

# %%
sns.distplot(df['coapplicant_income'])
plt.show()
df['coapplicant_income'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\Vasu\AppData\Local\Temp\ipykernel_7604\2413347626.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['coapplicant_income'])

# %% [markdown]
# ### Distribution of Loan Amount

# %%
sns.distplot(df['total_loan_amount'])
plt.show()
df['total_loan_amount'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\Vasu\AppData\Local\Temp\ipykernel_7604\1086884573.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_loan_amount'])

# %%
df.columns
# Out:
# Index(['loan_application_id', 'application_date', 'credit_score', 'loan_type',
#        'loan_category', 'interest_rate', 'loan_amount', 'loan_term',
#        'asset_value', 'interest_amount', 'coapplicant_name',
#        'coapplicant_income', 'status', 'loan_account_id', 'loan_interest_rate',
#        'loan_approved_date', 'loan_amount_availed', 'total_loan_amount',
#        'loan_amount_due', 'loan_status', 'loan_amount_paid',
#        'loan_completion_date', 'Customer Name', 'customer_gender',
#        'customer_age', 'customer_marital_status', 'customer_no_of_dependents',
#        'customer_education', 'customer_income', 'customer_occupation',
#        'customer_person_with_disability', 'customer_address',
#        'customer_date_of_joining', 'account_number', 'account_type',
#        'minimum_balance', 'account_balance', 'account_interest_rate',
#        'has_debit', 'has_credit', 'has_chequebook', 'has_netbanking',
# ...

# %% [markdown]
# ### Distribution of Asset Value

# %%
sns.distplot(df['asset_value'])
plt.show()
df['asset_value'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\Vasu\AppData\Local\Temp\ipykernel_7604\729609835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['asset_value'])

# %% [markdown]
# ### Distribution of Account Balance

# %%
sns.distplot(df['account_balance'])
plt.show()
df['account_balance'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\Vasu\AppData\Local\Temp\ipykernel_7604\1830472730.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['account_balance'])

# %% [markdown]
# ### Bivariant Analysis

# %% [markdown]
# #### 1. Is there a relationship between loan approval status and customer occupation?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Loan Approved ?', hue='customer_occupation', data=df)
plt.title('Loan Approval Status by Customer Occupation')
plt.xlabel('Loan Approval Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the above we can infer that there is a relationship between customer occupation and loan approval status.

# %% [markdown]
# #### 2. Is there a relationship between loan approval status and customer income?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Loan Approved ?', y='customer_income', data=df)
plt.title('Customer Income by Loan Approval Status')
plt.xlabel('Loan Approval Status')
plt.ylabel('Customer Income')
plt.show()

# %% [markdown]
# The above Boxplot show that customer Income has the effect on Loan Approval Status.

# %% [markdown]
# #### 3. How does loan approval status vary with account balance, marital status, customer_education, loan_amount_paid?

# %%
# Set up the subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Account Balance vs. Loan Approval Status
sns.boxplot(x='Loan Approved ?', y='account_balance', data=df, ax=axes[0, 0])
axes[0, 0].set_title('Account Balance by Loan Approval Status')

# Marital Status vs. Loan Approval Status
sns.countplot(x='customer_marital_status', hue='Loan Approved ?', data=df, ax=axes[0, 1])
axes[0, 1].set_title('Marital Status by Loan Approval Status')

# Customer Education vs. Loan Approval Status
sns.countplot(x='customer_education', hue='Loan Approved ?', data=df, ax=axes[1, 0])
axes[1, 0].set_title('Customer Education by Loan Approval Status')

# Loan Amount Due vs. Loan Approval Status
sns.boxplot(x='Loan Approved ?', y='credit_score', data=df, ax=axes[1, 1])
axes[1, 1].set_title('Credit Score by Loan Approval Status')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above series of char we can Infer that,
#    - If the Account Balance is more, then the chances of loan getting approved is more.
#    - comparitively Married Customers has more loans approved
#    - Matriculate Customers has more loans approved than others
#    - Credit score has no significant effect on Loan approval Process

# %% [markdown]
# #### 4. What is the relationship between loan amount, asset_value, and loan approval status?

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df[df['Loan Approved ?'] == 'Yes']['loan_amount'], df[df['Loan Approved ?'] == 'Yes']['asset_value'], color='blue', label='Approved')
plt.scatter(df[df['Loan Approved ?'] == 'No']['loan_amount'], df[df['Loan Approved ?'] == 'No']['asset_value'], color='red', label='Not Approved')
plt.title('Relationship between Loan Amount, Asset Value, and Loan Approval Status')
plt.xlabel('Loan Amount')
plt.ylabel('Asset Value')
plt.legend()
plt.show()

# %% [markdown]
# - The above chart infer that if the Asset value is more there is a higher chance of loan getting approved.

# %% [markdown]
# #### 5. Is there any interaction effect between customer income, loan amount, and account balance on loan approval status?

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(df, vars=['customer_income', 'loan_amount', 'account_balance'], hue='Loan Approved ?')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - Customer Income vs Loan Amount - Loan is approved when loan amount is less and customer income is more
# - Account Balance vs Customer Income - Loan is approved when both Account Balance and Customer Income is high

# %%
df.head(10)
# Out:
#   loan_application_id application_date  credit_score  loan_type loan_category  \
# 0            LA797244        10-Dec-14           519  Unsecured      Personal
# 1            LA332545        13-Dec-14           843  Unsecured     Education
# 2            LA576129        08-Dec-14           727  Unsecured      Personal
# 3            LA633665        18-Dec-14           394  Unsecured      Personal
# 4            LA164827        17-Dec-14           554  Unsecured      Personal
# 5            LA313841        22-Dec-14           730  Unsecured     Education
# 6            LA538959        23-Oct-15           316  Unsecured     Education
# 7            LA085669        29-Oct-16           737  Unsecured      Personal
# 8            LA247120        28-Apr-16           760  Unsecured      Personal
# 9            LA252975        03-Oct-16           404  Unsecured      Personal
#
#    interest_rate  loan_amount  loan_term  asset_value  interest_amount  ...  \
# ...

# %%
address_components = df['customer_address'].str.split(', ', expand=True)

# Rename the columns to meaningful names if needed
address_components.columns = ['Address_Line_1', 'line_2', 'Cust_city', 'Cust_State', 'PIN_Code']

# Concatenate the new address components with the original DataFrame
df = pd.concat([df, address_components], axis=1)

# %%
df.head(10)
# Out:
#   loan_application_id application_date  credit_score  loan_type loan_category  \
# 0            LA797244        10-Dec-14           519  Unsecured      Personal
# 1            LA332545        13-Dec-14           843  Unsecured     Education
# 2            LA576129        08-Dec-14           727  Unsecured      Personal
# 3            LA633665        18-Dec-14           394  Unsecured      Personal
# 4            LA164827        17-Dec-14           554  Unsecured      Personal
# 5            LA313841        22-Dec-14           730  Unsecured     Education
# 6            LA538959        23-Oct-15           316  Unsecured     Education
# 7            LA085669        29-Oct-16           737  Unsecured      Personal
# 8            LA247120        28-Apr-16           760  Unsecured      Personal
# 9            LA252975        03-Oct-16           404  Unsecured      Personal
#
#    interest_rate  loan_amount  loan_term  asset_value  interest_amount  ...  \
# ...

# %%
# Dropping the unwanted columns
df.drop(columns=['Address_Line_1', 'line_2', 'PIN_Code', 'minimum_balance', 'customer_address','application_date','loan_completion_date', 'loan_approved_date', 'account_last_active_date'], inplace=True)

# %%
df
# Out:
#      loan_application_id  credit_score  loan_type loan_category  \
# 0               LA797244           519  Unsecured      Personal
# 1               LA332545           843  Unsecured     Education
# 2               LA576129           727  Unsecured      Personal
# 3               LA633665           394  Unsecured      Personal
# 4               LA164827           554  Unsecured      Personal
# ...                  ...           ...        ...           ...
# 1562            LA677952           547  Unsecured     Education
# 1563            LA947692           659  Unsecured      Personal
# 1564            LA706547           609  Unsecured      Personal
# 1565            LA182797           693  Unsecured      Business
# 1566            LA799321           646  Unsecured      Business
#
#       interest_rate  loan_amount  loan_term  asset_value  interest_amount  \
# 0          5.000000       659475         42          NaN           115400
# ...

# %% [markdown]
# # Missing value Treatment

# %%
df.isnull().sum()
# Out:
# loan_application_id                  0
# credit_score                         0
# loan_type                            0
# loan_category                        0
# interest_rate                        0
# loan_amount                          0
# loan_term                            0
# asset_value                        772
# interest_amount                      0
# coapplicant_name                     0
# coapplicant_income                   0
# status                               0
# loan_account_id                      0
# loan_interest_rate                   0
# loan_amount_availed                  0
# total_loan_amount                  585
# loan_amount_due                      0
# loan_status                        585
# loan_amount_paid                     0
# Customer Name                        0
# customer_gender                      0
# customer_age                         0
# customer_marital_status              0
# customer_no_of_dependents            0
# ...

# %%
# Dropping the unwanted columns
df.drop(columns=['account_number','loan_application_id','loan_account_id','has_debit', 'has_credit', 'has_chequebook', 'has_netbanking', 'account_interest_rate'], inplace=True)

# %%
df.isnull().sum()
# Out:
# credit_score                         0
# loan_type                            0
# loan_category                        0
# interest_rate                        0
# loan_amount                          0
# loan_term                            0
# asset_value                        772
# interest_amount                      0
# coapplicant_name                     0
# coapplicant_income                   0
# status                               0
# loan_interest_rate                   0
# loan_amount_availed                  0
# total_loan_amount                  585
# loan_amount_due                      0
# loan_status                        585
# loan_amount_paid                     0
# Customer Name                        0
# customer_gender                      0
# customer_age                         0
# customer_marital_status              0
# customer_no_of_dependents            0
# customer_education                   0
# customer_income                    200
# ...

# %% [markdown]
# #### Median and Mode Imputation

# %%
# Mode imputation for specific column
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
df[['account_status']] = imputer.fit_transform(df[['account_status']])
df[['account_type']] = imputer.fit_transform(df[['account_type']])
df[['loan_status']] = imputer.fit_transform(df[['loan_status']])

# %%
df.isnull().sum()
# Out:
# credit_score                         0
# loan_type                            0
# loan_category                        0
# interest_rate                        0
# loan_amount                          0
# loan_term                            0
# asset_value                        772
# interest_amount                      0
# coapplicant_name                     0
# coapplicant_income                   0
# status                               0
# loan_interest_rate                   0
# loan_amount_availed                  0
# total_loan_amount                  585
# loan_amount_due                      0
# loan_status                          0
# loan_amount_paid                     0
# Customer Name                        0
# customer_gender                      0
# customer_age                         0
# customer_marital_status              0
# customer_no_of_dependents            0
# customer_education                   0
# customer_income                    200
# ...

# %%
# Impute missing values for 'account_balance' and 'customer_income' with the mean
df['account_balance'].fillna(df['account_balance'].median(), inplace=True)
df['customer_income'].fillna(df['customer_income'].mean(), inplace=True) # Since customer income has no outliers - using Mean imputation
df['asset_value'].fillna(df['asset_value'].median(), inplace=True)
df['total_loan_amount'].fillna(df['total_loan_amount'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# credit_score                       0
# loan_type                          0
# loan_category                      0
# interest_rate                      0
# loan_amount                        0
# loan_term                          0
# asset_value                        0
# interest_amount                    0
# coapplicant_name                   0
# coapplicant_income                 0
# status                             0
# loan_interest_rate                 0
# loan_amount_availed                0
# total_loan_amount                  0
# loan_amount_due                    0
# loan_status                        0
# loan_amount_paid                   0
# Customer Name                      0
# customer_gender                    0
# customer_age                       0
# customer_marital_status            0
# customer_no_of_dependents          0
# customer_education                 0
# customer_income                    0
# customer_occupation                0
# ...

# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd

# Define the bin edges
bin_edges = [0, 20, 30, 40, 50, 60, 70, float('inf')]  # Define the age ranges for each bin

# Define the bin labels
bin_labels = ['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71+']

# Create the bins
df['Age_group'] = pd.cut(df['customer_age'], bins=bin_edges, labels=bin_labels, right=False)

# %%
# Loan-to-Asset Ratio
df['Loan_to_Asset_Ratio'] = df['loan_amount'] / df['asset_value']

# %%
# Total Loan Repayment
df['Total_Loan_Repayment'] = df['loan_amount'] + df['interest_amount']

# %%
# Debt to Income Ratio
df['debt_to_income_ratio'] = df['total_loan_amount'] / df['customer_income']

# %%
# Coapplicant Existence
df['coapplicant_existence'] = df['coapplicant_name'].apply(lambda x: 0 if pd.isnull(x) else 1)

# %%
# Loan Amount Category
bins = [0, 100000, 500000, 1000000, np.inf]
labels = ['Small', 'Medium', 'Large', 'Very Large']
df['Loan_Amount_Category'] = pd.cut(df['total_loan_amount'], bins=bins, labels=labels)

# %%
# Total Income including Coapplicant
df['Total_Income'] = df['customer_income'] + df['coapplicant_income']

# %%
df.isnull().sum()
# Out:
# credit_score                       0
# loan_type                          0
# loan_category                      0
# interest_rate                      0
# loan_amount                        0
# loan_term                          0
# asset_value                        0
# interest_amount                    0
# coapplicant_name                   0
# coapplicant_income                 0
# status                             0
# loan_interest_rate                 0
# loan_amount_availed                0
# total_loan_amount                  0
# loan_amount_due                    0
# loan_status                        0
# loan_amount_paid                   0
# Customer Name                      0
# customer_gender                    0
# customer_age                       0
# customer_marital_status            0
# customer_no_of_dependents          0
# customer_education                 0
# customer_income                    0
# customer_occupation                0
# ...

# %% [markdown]
# #### Removing Highly correlated variables

# %%
columns_to_drop = [
    'loan_amount', 'interest_amount', 'loan_amount_availed','loan_amount_due','branch_name', 'loan_interest_rate', 'status', 'loan_amount_due', 'loan_status','Cust_State', 'customer_age', 'loan_amount_paid'
]

df.drop(columns=columns_to_drop, inplace=True)

# %%
# Filter out non-numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate correlation matrix
corr = numeric_df.corr()

# %%
# Plot half correlation heatmap
plt.figure(figsize=(35, 30))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, cmap='coolwarm')

# Add title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()

# %% [markdown]
# # Outliers Identification & Treatment

# %% [markdown]
# ## Outliers Identification

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#        credit_score  interest_rate    loan_term   asset_value  \
# count   1567.000000    1567.000000  1567.000000  1.567000e+03
# mean     575.529675       6.573607    44.065093  1.283955e+06
# std      156.431744       1.704933    15.022532  1.880133e+06
# min      300.000000       2.036817    24.000000  5.119600e+04
# 25%      447.000000       5.216322    33.000000  7.124220e+05
# 50%      573.000000       7.000000    43.000000  7.240480e+05
# 75%      710.000000       8.000000    53.000000  7.367890e+05
# max      850.000000      10.000000   120.000000  9.939018e+06
#
#        coapplicant_income  total_loan_amount  customer_no_of_dependents  \
# count        1.567000e+03       1.567000e+03                1567.000000
# mean         1.045608e+06       1.385721e+06                   2.908743
# std          5.510839e+05       1.538662e+06                   1.966506
# min          1.221900e+05       5.140000e+04                   0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of seaborn
sns.set(style="whitegrid")

# %%
# Create a box plot for credit_score
plt.figure(figsize=(10, 6))
sns.boxplot(x='credit_score', data=df, palette='Set1')
plt.title('Box Plot of credit_scoret')
plt.xlabel('Credit Score')
plt.show()

# %%
# Create a box plot for loan_term
plt.figure(figsize=(10, 6))
sns.boxplot(x='loan_term', data=df, palette='Set1')
plt.title('Box Plot of loan_term')
plt.xlabel('loan_term')
plt.show()

# %%
# Create a box plot for asset_value
plt.figure(figsize=(10, 6))
sns.boxplot(x='asset_value', data=df, palette='Set1')
plt.title('Box Plot of asset_value')
plt.xlabel('asset_value')
plt.show()

# %%
# Create a box plot for coapplicant_income
plt.figure(figsize=(10, 6))
sns.boxplot(x='coapplicant_income', data=df, palette='Set1')
plt.title('Box Plot of coapplicant_income')
plt.xlabel('coapplicant_income')
plt.show()

# %%
# Create a box plot for customer_income
plt.figure(figsize=(10, 6))
sns.boxplot(x='customer_income', data=df, palette='Set1')
plt.title('Box Plot of customer_income')
plt.xlabel('customer_income')
plt.show()

# %%
# Create a box plot for account_balance
plt.figure(figsize=(10, 6))
sns.boxplot(x='account_balance', data=df, palette='Set1')
plt.title('Box Plot of account_balance')
plt.xlabel('account_balance')
plt.show()

# %%
# Create a box plot for total_loan_amount
plt.figure(figsize=(10, 6))
sns.boxplot(x='total_loan_amount', data=df, palette='Set1')
plt.title('Box Plot of total_loan_amount')
plt.xlabel('total_loan_amount')
plt.show()

# %% [markdown]
# - Account balance
# - Asset value
# - Loan term
# - Total Loan amount
#
# The above 4 variables has outliers, since Account Balance and Asset value may vary widely based on individual circumstances, so extreme values might still be valid and for the loan term is based on the bank and other factors related to the bank so it doesn't require treatment.
#
# The outlier in total loan amount has significant impact so it is treated using winsorization technique.

# %%
# Rename the column
df.rename(columns={'Loan Approved ?': 'Loan_Status'}, inplace=True)

# %%
df.columns
# Out:
# Index(['credit_score', 'loan_type', 'loan_category', 'interest_rate',
#        'loan_term', 'asset_value', 'coapplicant_name', 'coapplicant_income',
#        'total_loan_amount', 'Customer Name', 'customer_gender',
#        'customer_marital_status', 'customer_no_of_dependents',
#        'customer_education', 'customer_income', 'customer_occupation',
#        'customer_person_with_disability', 'customer_date_of_joining',
#        'account_type', 'account_balance', 'account_status', 'Loan_Status',
#        'Cust_city', 'Age_group', 'Loan_to_Asset_Ratio', 'Total_Loan_Repayment',
#        'debt_to_income_ratio', 'coapplicant_existence', 'Loan_Amount_Category',
#        'Total_Income'],
#       dtype='object')

# %% [markdown]
# ### Outlier treatment using Winsorization

# %%
from scipy.stats.mstats import winsorize

# Winsorize the total_loan_amount column
df['total_loan_amount_winsorized'] = winsorize(df['total_loan_amount'], limits=[0.05, 0.05])

# Drop the original total_loan_amount column
df.drop(columns=['total_loan_amount'], inplace=True)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Logistic Regression

# %%
X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

# %%
X = pd.get_dummies(X)
df = pd.get_dummies(df)

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

model = LogisticRegression()
model.fit(x_train, y_train)

pred_cv = model.predict(x_valid)

print('Model Accuracy = ', accuracy_score(y_valid, pred_cv))
print('Model F1-Score = ', f1_score(y_valid, pred_cv, pos_label='Yes'))
# Out:
# Model Accuracy =  0.7261146496815286
# Model F1-Score =  0.8100147275405009

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Fit logistic regression model
model = LogisticRegression()
model.fit(x_train, y_train)

# Make predictions on the validation set
pred_cv = model.predict(x_valid)

# Compute predicted probabilities for the positive class (class 1)
y_probs = model.predict_proba(x_valid)[:, 1]

# Encode target variable
label_encoder = LabelEncoder()
y_valid_encoded = label_encoder.fit_transform(y_valid)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_valid_encoded, y_probs)

# Compute AUC score
auc = roc_auc_score(y_valid_encoded, y_probs)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Stratified K-fold Classifier

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

# Define the number of splits for Stratified K-Fold
n_splits = 5  # You can adjust the number of splits as needed

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Lists to store accuracy and F1 scores for each fold
accuracy_scores = []
f1_scores = []

# Perform cross-validation
for train_index, test_index in skf.split(X, y):
    # Split the data into train and test sets for this fold
    X_train_fold, X_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    
    # Initialize and train the model
    model = LogisticRegression()
    model.fit(X_train_fold, y_train_fold)
    
    # Make predictions on the test set
    pred_fold = model.predict(X_test_fold)
    
    # Calculate accuracy and F1 score for this fold
    accuracy = accuracy_score(y_test_fold, pred_fold)
    f1 = f1_score(y_test_fold, pred_fold, pos_label='Yes')
    
    # Append scores to the lists
    accuracy_scores.append(accuracy)
    f1_scores.append(f1)

# Calculate mean scores across all folds
mean_accuracy = sum(accuracy_scores) / len(accuracy_scores)
mean_f1 = sum(f1_scores) / len(f1_scores)

# Print mean scores
print('Mean Accuracy =', mean_accuracy)
print('Mean F1-Score =', mean_f1)
# Out:
# Mean Accuracy = 0.7466514722940112
# Mean F1-Score = 0.8281067929737285

# %% [markdown]
# ### ROC Curve for Stratified K fold classifier

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import numpy as np

# Define the number of splits for Stratified K-Fold
n_splits = 5  # You can adjust the number of splits as needed

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Lists to store true positive rate (TPR), false positive rate (FPR), and AUC for each fold
tpr_list = []
fpr_list = []
auc_list = []

# Define a set of common thresholds
thresholds = np.linspace(0, 1, 100)

# Perform cross-validation
for train_index, test_index in skf.split(X, y):
    # Split the data into train and test sets for this fold
    X_train_fold, X_test_fold = X.iloc[train_index], X.iloc[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]
    
    # Initialize and train the model
    model = LogisticRegression()
    model.fit(X_train_fold, y_train_fold)
    
    # Make predictions on the test set
    pred_probs = model.predict_proba(X_test_fold)[:, 1]
    
    # Convert categorical labels to binary labels
    y_test_fold_binary = np.where(y_test_fold == 'Yes', 1, 0)
    
    # Compute ROC curve
    fpr, tpr, _ = roc_curve(y_test_fold_binary, pred_probs)
    
    # Interpolate TPR and FPR values at common thresholds
    interpolated_tpr = np.interp(thresholds, fpr, tpr)
    interpolated_fpr = thresholds
    
    # Append interpolated TPR, FPR, and AUC to the lists
    tpr_list.append(interpolated_tpr)
    fpr_list.append(interpolated_fpr)
    auc_list.append(roc_auc_score(y_test_fold_binary, pred_probs))

# Calculate mean TPR, FPR, and AUC across all folds
mean_tpr = np.mean(tpr_list, axis=0)
mean_fpr = np.mean(fpr_list, axis=0)
mean_auc = np.mean(auc_list)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(mean_fpr, mean_tpr, color='blue', lw=2, label=f'Mean ROC Curve (AUC = {mean_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Mean Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
import pickle

# Save the model to a file
with open('logistic_regression_model_loan.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
with open('logistic_regression_model_loan.pkl', 'rb') as file:
    pickle.load(file)
